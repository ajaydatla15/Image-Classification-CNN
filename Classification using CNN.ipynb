# %%
# !pip install opencv-python

# %%
from tensorflow.keras.applications.inception_resnet_v2 import InceptionResNetV2 #a convolutional neural network that is trained on more than a million images from the ImageNet database
import os
from tensorflow.keras.applications.inception_resnet_v2 import preprocess_input#Preprocesses a tensor or Numpy array encoding a batch of images.
from tensorflow.keras.layers import GlobalAveragePooling2D,Dense,Dropout#a pooling operation designed to replace fully connected layers in classical CNN
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import SGD,Adam #to reduce loss by changing learning rate, weights
import ssl#securing an internet connection by encrypting data sent between a website and a browser
#his code block sets the stage for building and training a neural network model using the InceptionResNetV2 architecture. It imports necessary modules, defines the architecture, and prepares the environment for further processing.
ssl._create_default_https_context = ssl._create_unverified_context

# %%
ir=InceptionResNetV2(weights="imagenet",include_top=False)

# %%
x=ir.output
x=GlobalAveragePooling2D()(x)
x=Dropout(0.20)(x)
x=Dense(1024,activation="relu")(x)
preds=Dense(2,activation="softmax")(x)
model=Model(inputs=ir.input,outputs=preds)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ...
#  input_1 (InputLayer)        [(None, None, None, 3)]      0         []
#
#  conv2d (Conv2D)             (None, None, None, 32)       864       ['input_1[0][0]']
#
#  batch_normalization (Batch  (None, None, None, 32)       96        ['conv2d[0][0]']
#  Normalization)
#
#  activation (Activation)     (None, None, None, 32)       0         ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)           (None, None, None, 32)       9216      ['activation[0][0]']
#
#  batch_normalization_1 (Bat  (None, None, None, 32)       96        ['conv2d_1[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, None, None, 32)       0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
# ...

# %%
model.compile(optimizer=SGD(lr=0.0001,momentum=0.9),loss="categorical_crossentropy",metrics=['accuracy'])

# %%
from PIL import Image
import cv2
import numpy as np
p1="/Users/ajayramaraju/Desktop/My Research/Projects/CNN micro_structures/augmented yes"
p2="/Users/ajayramaraju/Desktop/My Research/Projects/CNN micro_structures/augmented no"
x=[]
y=[]
for f in os.listdir(p1):
    if ".jpeg" in f:
        im=cv2.imread(p1+"/"+f)
        label=[0,1]
        im=cv2.resize(im,dsize=(299,299))
        
        im=preprocess_input(im)
       
        x.append(im)
        y.append(label)
for f in os.listdir(p2):
    if ".jpeg" in f:
        im=cv2.imread(p2+"/"+f)
       
        label=[1,0]
        im=cv2.resize(im,dsize=(299,299))
        
        im=preprocess_input(im)
        x.append(im)
        y.append(label)

x=np.array(x)
y=np.array(y)

# %%
print(x.shape,y.shape)
# Out:
# (31, 299, 299, 3) (31, 2)

# %%
model.fit(x,y,epochs=10)
# Out:
# Epoch 1/10
# 1/1 [==============================] - 20s 20s/step - loss: 0.7122 - accuracy: 0.4194
# Epoch 2/10
# 1/1 [==============================] - 12s 12s/step - loss: 0.6333 - accuracy: 0.6129
# Epoch 3/10
# 1/1 [==============================] - 13s 13s/step - loss: 0.5176 - accuracy: 0.8387
# Epoch 4/10
# 1/1 [==============================] - 12s 12s/step - loss: 0.4697 - accuracy: 0.9355
# Epoch 5/10
# 1/1 [==============================] - 14s 14s/step - loss: 0.4154 - accuracy: 0.9677
# Epoch 6/10
# 1/1 [==============================] - 14s 14s/step - loss: 0.3059 - accuracy: 1.0000
# Epoch 7/10
# 1/1 [==============================] - 15s 15s/step - loss: 0.2384 - accuracy: 1.0000
# Epoch 8/10
# 1/1 [==============================] - 14s 14s/step - loss: 0.1645 - accuracy: 1.0000
# Epoch 9/10
# 1/1 [==============================] - 13s 13s/step - loss: 0.1108 - accuracy: 1.0000
# Epoch 10/10
# ...

# %%
model.save("Micro Structures.h5")

# %%
from sklearn.metrics import accuracy_score,mean_squared_error
print("Accuracy :", accuracy_score(ans,y1)*100)

# %%
import tensorflow as tf
predicting_model = tf.keras.models.load_model("Micro Structures.h5");

# %%
p="/Users/ajayramaraju/Desktop/My Research/Projects/CNN micro_structures/reshaped images/no/image_0_8288.jpeg"
im=cv2.imread(p)
im=cv2.resize(im,dsize=(299,299))
im=preprocess_input(im)
im=im.reshape(1,299,299,3)
res=predicting_model.predict(im)
print (res)
res[0][0]=round(res[0][0])
res[0][1]=round(res[0][1])
if(res[0][1]==0): 
  print("Not Efficient")
else:
  print("Efficient")
# Out:
# 1/1 [==============================] - 0s 173ms/step
# [[0.8350979  0.16490208]]
# Not Efficient
